# %%
# Useful imports
import os
from pathlib import Path
import tempfile
import hydra
import sys

# %% [markdown]
# ### User Configuration Section

# %%
RESULT_FOLDER = "REPLACE_WITH_RESULT_PATH" # simulation result absolute path (e.g., "/data/nuplan-v1.1/exp/exp/simulation/closed_loop_nonreactive_agents/diffusion_planner/val14/diffusion_planner_release/model_2025-01-25-18-29-09")
env_variables = {
    "NUPLAN_DEVKIT_ROOT": "/home/yiliu/nuplan_learning/nuplan-devkit",  # nuplan-devkit absolute path (e.g., "/home/user/nuplan-devkit")
    "NUPLAN_DATA_ROOT": "/home/yiliu/nuplan_learning/nuplan-devkit/nuplan/dataset/nuplan-v1.1/splits", # nuplan dataset absolute path (e.g. "/data")
    "NUPLAN_MAPS_ROOT": "/home/yiliu/nuplan_learning/nuplan-devkit/nuplan/dataset/maps", # nuplan maps absolute path (e.g. "/data/nuplan-v1.1/maps")
    "NUPLAN_EXP_ROOT": "/home/yiliu/nuplan_learning/nuplan-devkit/nuplan/dataset/exp", # nuplan experiment absolute path (e.g. "/data/nuplan-v1.1/exp")
    "NUPLAN_SIMULATION_ALLOW_ANY_BUILDER":"1"
}

for k, v in env_variables.items():
    os.environ[k] = v

# Location of path with all nuBoard configs
CONFIG_PATH = '../../nuplan_learning/nuplan-devkit/nuplan/planning/script/config/nuboard' # relative path to nuplan-devkit

# %%
CONFIG_NAME = 'default_nuboard'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

ml_planner_simulation_folder = "/home/yiliu/nuplan_learning/nuplan-devkit/nuplan/dataset/exp/exp/simulation/closed_loop_nonreactive_agents/diffusion_planner/test14-random/game_theoretic/latest_2026-03-05-21-28-22"
ml_planner_simulation_folder = [dp for dp, _, fn in os.walk(ml_planner_simulation_folder) if True in ['.nuboard' in x for x in fn]]

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    #'scenario_builder=nuplan',  # set the database (same as simulation) used to fetch data for visualization
    'scenario_builder=nuplan_challenge',
    f'simulation_path={ml_planner_simulation_folder}',  # nuboard file path(s), if left empty the user can open the file inside nuBoard
    'hydra.searchpath=[pkg://diffusion_planner.config.scenario_filter, pkg://diffusion_planner.config, pkg://nuplan.planning.script.config.common, pkg://nuplan.planning.script.experiments]',
    'port_number=6599'
])

# %%
from nuplan.planning.script.run_nuboard import main as main_nuboard

# Run nuBoard
main_nuboard(cfg)
# Out:
# INFO:nuplan.planning.script.builders.scenario_building_builder:Building AbstractScenarioBuilder...
# INFO:nuplan.planning.script.builders.scenario_building_builder:Building AbstractScenarioBuilder...DONE!
# INFO:nuplan.planning.nuboard.nuboard:Opening Bokeh application on http://localhost:6599/
# INFO:nuplan.planning.nuboard.nuboard:Async rendering is set to: True
# INFO:bokeh.server.server:Starting Bokeh server version 2.4.3 (running on Tornado 6.5.4)
# WARNING:bokeh.server.util:Host wildcard '*' will allow connections originating from multiple (or possibly all) hostnames or IPs. Use non-wildcard values to restrict access explicitly
# INFO:bokeh.server.tornado:User authentication hooks NOT provided (default user enabled)
# INFO:nuplan.planning.nuboard.base.simulation_tile:Minimum frame time=0.017 s
# INFO:nuplan.planning.nuboard.tabs.scenario_tab:Rending scenario plot takes 0.0010 seconds.
# INFO:tornado.access:200 GET / (127.0.0.1) 1589.20ms
# INFO:tornado.access:200 GET / (127.0.0.1) 1589.20ms
# INFO:tornado.access:101 GET /ws (127.0.0.1) 0.69ms
# INFO:tornado.access:101 GET /ws (127.0.0.1) 0.69ms
# INFO:bokeh.server.views.ws:WebSocket connection opened
# INFO:bokeh.server.views.ws:ServerConnection created
# ERROR:bokeh.server.protocol_handler:error handling message
#  message: Message 'PATCH-DOC' content: {'events': [{'kind': 'MessageSent', 'msg_type': 'bokeh_event', 'msg_data': {'event_name': 'button_click', 'event_values': {}}}], 'references': []}
#  error: PermissionError(13, 'Permission denied')
# Traceback (most recent call last):
#   File "/home/yiliu/miniconda3_linux/envs/diffusion_planner/lib/python3.9/site-packages/bokeh/server/protocol_handler.py", line 97, in handle
#     work = await handler(message, connection)
#   File "/home/yiliu/miniconda3_linux/envs/diffusion_planner/lib/python3.9/site-packages/bokeh/server/session.py", line 95, in _needs_document_lock_wrapper
#     result = func(self, *args, **kwargs)
#   File "/home/yiliu/miniconda3_linux/envs/diffusion_planner/lib/python3.9/site-packages/bokeh/server/session.py", line 289, in _handle_patch
#     message.apply_to_document(self.document, self)
#   File "/home/yiliu/miniconda3_linux/envs/diffusion_planner/lib/python3.9/site-packages/bokeh/protocol/messages/patch_doc.py", line 115, in apply_to_document
#     invoke_with_curdoc(doc, lambda: doc.apply_json_patch(self.content, setter))
#   File "/home/yiliu/miniconda3_linux/envs/diffusion_planner/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 408, in invoke_with_curdoc
#     return f()
#   File "/home/yiliu/miniconda3_linux/envs/diffusion_planner/lib/python3.9/site-packages/bokeh/protocol/messages/patch_doc.py", line 115, in <lambda>
#     invoke_with_curdoc(doc, lambda: doc.apply_json_patch(self.content, setter))
#   File "/home/yiliu/miniconda3_linux/envs/diffusion_planner/lib/python3.9/site-packages/bokeh/document/document.py", line 391, in apply_json_patch
#     DocumentPatchedEvent.handle_json(self, event_json, references, setter)
#   File "/home/yiliu/miniconda3_linux/envs/diffusion_planner/lib/python3.9/site-packages/bokeh/document/events.py", line 259, in handle_json
#     handler(doc, event_json, references, setter)
#   File "/home/yiliu/miniconda3_linux/envs/diffusion_planner/lib/python3.9/site-packages/bokeh/document/events.py", line 300, in _handle_json
#     cb(event_json["msg_data"])
#   File "/home/yiliu/miniconda3_linux/envs/diffusion_planner/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 355, in trigger_json_event
#     model._trigger_event(event)
#   File "/home/yiliu/miniconda3_linux/envs/diffusion_planner/lib/python3.9/site-packages/bokeh/util/callback_manager.py", line 119, in _trigger_event
#     self.document.callbacks.notify_event(cast(Model, self), event, invoke)
#   File "/home/yiliu/miniconda3_linux/envs/diffusion_planner/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 247, in notify_event
#     invoke_with_curdoc(doc, callback_invoker)
#   File "/home/yiliu/miniconda3_linux/envs/diffusion_planner/lib/python3.9/site-packages/bokeh/document/callbacks.py", line 408, in invoke_with_curdoc
#     return f()
#   File "/home/yiliu/miniconda3_linux/envs/diffusion_planner/lib/python3.9/site-packages/bokeh/util/callback_manager.py", line 113, in invoke
#     cast(EventCallbackWithoutEvent, callback)()
#   File "/home/yiliu/nuplan_learning/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py", line 568, in _scenario_modal_query_button_on_click
#     self._update_scenario_plot()
#   File "/home/yiliu/nuplan_learning/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py", line 475, in _update_scenario_plot
#     self._simulation_plots = self._render_simulations()
#   File "/home/yiliu/nuplan_learning/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py", line 1002, in _render_simulations
#     self._simulation_figure_data = self.simulation_tile.render_simulation_tiles(
#   File "/home/yiliu/nuplan_learning/nuplan-devkit/nuplan/planning/nuboard/base/simulation_tile.py", line 377, in render_simulation_tiles
#     self.init_simulations(figure_sizes=figure_sizes)
#   File "/home/yiliu/nuplan_learning/nuplan-devkit/nuplan/planning/nuboard/base/simulation_tile.py", line 318, in init_simulations
#     simulation_figure = self._create_initial_figure(figure_index=figure_index, figure_sizes=figure_sizes)
#   File "/home/yiliu/nuplan_learning/nuplan-devkit/nuplan/planning/nuboard/base/simulation_tile.py", line 278, in _create_initial_figure
#     simulation_log = SimulationLog.load_data(simulation_file)
#   File "/home/yiliu/nuplan_learning/nuplan-devkit/nuplan/planning/simulation/simulation_log.py", line 100, in load_data
#     data = pickle.loads(data)
#   File "/home/yiliu/nuplan_learning/nuplan-devkit/nuplan/planning/scenario_builder/nuplan_db/nuplan_scenario.py", line 122, in __init__
#     self._log_file = download_file_if_necessary(self._data_root, self._log_file_load_path)
#   File "/home/yiliu/nuplan_learning/nuplan-devkit/nuplan/planning/scenario_builder/nuplan_db/nuplan_scenario_utils.py", line 128, in download_file_if_necessary
#     os.makedirs(data_root, exist_ok=True)
#   File "/home/yiliu/miniconda3_linux/envs/diffusion_planner/lib/python3.9/os.py", line 215, in makedirs
#     makedirs(head, exist_ok=exist_ok)
#   File "/home/yiliu/miniconda3_linux/envs/diffusion_planner/lib/python3.9/os.py", line 215, in makedirs
#     makedirs(head, exist_ok=exist_ok)
#   File "/home/yiliu/miniconda3_linux/envs/diffusion_planner/lib/python3.9/os.py", line 215, in makedirs
#     makedirs(head, exist_ok=exist_ok)
#   [Previous line repeated 5 more times]
#   File "/home/yiliu/miniconda3_linux/envs/diffusion_planner/lib/python3.9/os.py", line 225, in makedirs
#     mkdir(name, mode)
# PermissionError: [Errno 13] Permission denied: '/root/autodl-tmp'
# /home/yiliu/miniconda3_linux/envs/diffusion_planner/lib/python3.9/site-packages/bokeh/server/protocol_handler.py:101: RuntimeWarning: coroutine 'WSHandler.send_message' was never awaited
#   work = connection.error(message, repr(e))
# INFO:bokeh.server.views.ws:WebSocket connection closed: code=1001, reason=None
